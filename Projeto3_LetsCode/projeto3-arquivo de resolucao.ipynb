# %% [markdown]
# # 📊 Relatório III
# >  Integrantes:
# > * Bruno
# > * Daniel
# > * Hallynny
# > * Jaiana
# > * Thalles
# > * Youlia

# %% [markdown]
# # 🔎 Fazer uma análise exploratória de dados através dos anos 2015 até 2019.

# %% [markdown]
# Abaixo são feitas as seguintes ações:
#
# Importa-se as biliotecas;\
# Carrega-se o dataframe (df) de cada ano;\
# Apresenta-se as primeiras linhas de cada df para visualização.

# %%
import pandas as pd 
import numpy as np

# %%
df_2015 = pd.read_csv('bases/2015.csv')
df_2016 = pd.read_csv('bases/2016.csv')
df_2017 = pd.read_csv('bases/2017.csv')
df_2018 = pd.read_csv('bases/2018.csv')
df_2019 = pd.read_csv('bases/2019.csv')

# %%
display(df_2015.head(3))
display(df_2016.head(3))
display(df_2017.head(3))
display(df_2018.head(3))
display(df_2019.head(3))
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
# 2  Iceland               3            7.504      7.622030     7.385970
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341

# %% [markdown]
# ## 1. Quais foram as alterações ano a ano no ranking dos primeiros 10 países; 📆

# %% [markdown]
# Abaixo são feitas as seguintes ações:
#
# Atribui-se o top 10 de cada ano a uma variável adequada;\
# Cria-se um df contendo todos os top 10 organizados por colunas;\
# Apresenta-se a frequência de aparição de cada país nos 5 anos estudados;\
# Escreve-se o arquio em xlsx.

# %%
top10_2015 = df_2015.nsmallest(10, 'Happiness Rank')['Country']
top10_2016 = df_2016.nsmallest(10, 'Happiness Rank')['Country']
top10_2017 = df_2017.nsmallest(10, 'Happiness.Rank')['Country']
top10_2018 = df_2018.nsmallest(10, 'Overall rank')['Country or region']
top10_2019 = df_2019.nsmallest(10, 'Overall rank')['Country or region']

top_10 = pd.DataFrame({'2015': top10_2015, '2016': top10_2016, '2017': top10_2017, '2018': top10_2018, '2019': top10_2019})
top_10.index = top_10.index + 1
top_10
# Out:
#            2015         2016         2017         2018         2019
# 1   Switzerland      Denmark       Norway      Finland      Finland
# 2       Iceland  Switzerland      Denmark       Norway      Denmark
# 3       Denmark      Iceland      Iceland      Denmark       Norway
# 4        Norway       Norway  Switzerland      Iceland      Iceland
# 5        Canada      Finland      Finland  Switzerland  Netherlands
# 6       Finland       Canada  Netherlands  Netherlands  Switzerland
# 7   Netherlands  Netherlands       Canada       Canada       Sweden
# 8        Sweden  New Zealand  New Zealand  New Zealand  New Zealand
# 9   New Zealand    Australia       Sweden       Sweden       Canada
# 10    Australia       Sweden    Australia    Australia      Austria

# %%
top_10.melt()['value'].value_counts()
# Out:
# Switzerland    5
# Iceland        5
# Denmark        5
# Norway         5
# Canada         5
# Finland        5
# Netherlands    5
# Sweden         5
# New Zealand    5
# Australia      4
# Austria        1
# Name: value, dtype: int64

# %%
top_10.to_excel('top_10_anos.xlsx')

# %% [markdown]
# ## 2. Considerando a média de todas as variáveis, quais foram as 3 variáveis que mais mudaram ano a ano.(Sem contar o score ou ranking) 📆

# %% [markdown]
# Abaixo são feitas as seguintes ações:
#
# Atribui-se as colunas de interesse de cada ano a uma variável adequada e cria-se a coluna de ano;\
# Concatena-se todas os df;\
# Agrupa-se as linhas pelo ano;\
# Calcula-se a média de cada variável ano a ano;\
# Calcula-se as variações nominais e percentuais das variáveis de um ano ao ano seguinte;\
# Apresenta-se a média, o desvio padrão e valores máximo e mínimo de cada variável em todos os anos amostrados (de 2015 a 2019)

# %%
df_2015.info()
df_2015_numeros = df_2015.drop(columns = ['Region', 'Happiness Rank', 'Standard Error', 'Dystopia Residual'])
df_2015_numeros['Year'] = '2015'
df_2015_numeros.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB
#        Country  Happiness Score  Economy (GDP per Capita)   Family  \
# 0  Switzerland            7.587                   1.39651  1.34951
# 1      Iceland            7.561                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Year
# 0     0.29678  2015
# 1     0.43630  2015

# %%
df_2016.info()
df_2016_numeros = df_2016.drop(columns = ['Region', 'Happiness Rank', 'Lower Confidence Interval',
                                          'Upper Confidence Interval', 'Dystopia Residual'])
df_2016_numeros['Year'] = '2016'
df_2016_numeros.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
#  12  Dystopia Residual              157 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.1+ KB
#        Country  Happiness Score  Economy (GDP per Capita)   Family  \
# 0      Denmark            7.526                   1.44178  1.16374
# 1  Switzerland            7.509                   1.52733  1.14524
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.79504  0.57941                        0.44453
# 1                   0.86303  0.58557                        0.41203
#
#    Generosity  Year
# 0     0.36171  2016
# 1     0.28083  2016

# %%
def trocar_colunas(df, coluna_1, coluna_2):
    colunas_lista = list(df.columns)
    x, y = colunas_lista.index(coluna_1), colunas_lista.index(coluna_2)
    colunas_lista[y], colunas_lista[x] = colunas_lista[x], colunas_lista[y]
    df = df[colunas_lista]

    return df

# %%
df_2017.info()
df_2017_numeros = df_2017.drop(columns = ['Happiness.Rank', 'Whisker.high', 'Whisker.low', 'Dystopia.Residual'])
df_2017_numeros = trocar_colunas(df_2017_numeros, 'Generosity', 'Trust..Government.Corruption.')                                        
df_2017_numeros.columns = ["Country",  'Happiness Score','Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom','Trust (Government Corruption)', 'Generosity']
df_2017_numeros['Year'] = '2017'
df_2017_numeros.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.7+ KB
#    Country  Happiness Score  Economy (GDP per Capita)    Family  \
# 0   Norway            7.537                  1.616463  1.533524
# 1  Denmark            7.522                  1.482383  1.551122
#
#    Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                  0.796667  0.635423                       0.315964
# 1                  0.792566  0.626007                       0.400770
#
#    Generosity  Year
# 0    0.362012  2017
# 1    0.355280  2017

# %%
df_2018.info()
df_2018_numeros = df_2018.drop(columns = ['Overall rank'])
df_2018_numeros = trocar_colunas(df_2018_numeros, 'Generosity', 'Perceptions of corruption')
df_2018_numeros.columns = [ 'Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom','Trust (Government Corruption)', 'Generosity']
df_2018_numeros['Year'] = '2018'
df_2018_numeros.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
#    Country  Happiness Score  Economy (GDP per Capita)  Family  \
# 0  Finland            7.632                     1.305   1.592
# 1   Norway            7.594                     1.456   1.582
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.874    0.681                          0.393
# 1                     0.861    0.686                          0.340
#
#    Generosity  Year
# 0       0.202  2018
# 1       0.286  2018

# %%
df_2019_numeros = df_2019.drop(columns = ['Overall rank'])
df_2019_numeros = trocar_colunas(df_2019_numeros, 'Generosity', 'Perceptions of corruption')
df_2019_numeros.columns = ['Country', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom','Trust (Government Corruption)', 'Generosity']
df_2019_numeros['Year'] = '2019'
df_2019_numeros.head()
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)  Family  \
# 0      Finland            7.769                     1.340   1.587
# 1      Denmark            7.600                     1.383   1.573
# 2       Norway            7.554                     1.488   1.582
# 3      Iceland            7.494                     1.380   1.624
# 4  Netherlands            7.488                     1.396   1.522
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.986    0.596                          0.393
# 1                     0.996    0.592                          0.410
# 2                     1.028    0.603                          0.341
# 3                     1.026    0.591                          0.118
# 4                     0.999    0.557                          0.298
#
#    Generosity  Year
# 0       0.153  2019
# 1       0.252  2019
# 2       0.271  2019
# 3       0.354  2019
# 4       0.322  2019

# %%
df_5_anos = pd.concat([df_2015_numeros, df_2016_numeros, df_2017_numeros, df_2018_numeros, df_2019_numeros], axis = 0).reset_index(drop=True)
df_5_anos
# Out:
#                       Country  Happiness Score  Economy (GDP per Capita)  \
# 0                 Switzerland            7.587                   1.39651
# 1                     Iceland            7.561                   1.30232
# 2                     Denmark            7.527                   1.32548
# 3                      Norway            7.522                   1.45900
# 4                      Canada            7.427                   1.32629
# ..                        ...              ...                       ...
# 777                    Rwanda            3.334                   0.35900
# 778                  Tanzania            3.231                   0.47600
# 779               Afghanistan            3.203                   0.35000
# 780  Central African Republic            3.083                   0.02600
# 781               South Sudan            2.853                   0.30600
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# 1    1.40223                   0.94784  0.62877
# 2    1.36058                   0.87464  0.64938
# 3    1.33095                   0.88521  0.66973
# 4    1.32261                   0.90563  0.63297
# ..       ...                       ...      ...
# 777  0.71100                   0.61400  0.55500
# 778  0.88500                   0.49900  0.41700
# 779  0.51700                   0.36100  0.00000
# 780  0.00000                   0.10500  0.22500
# 781  0.57500                   0.29500  0.01000
#
#      Trust (Government Corruption)  Generosity  Year
# 0                          0.41978     0.29678  2015
# 1                          0.14145     0.43630  2015
# 2                          0.48357     0.34139  2015
# 3                          0.36503     0.34699  2015
# 4                          0.32957     0.45811  2015
# ..                             ...         ...   ...
# 777                        0.41100     0.21700  2019
# 778                        0.14700     0.27600  2019
# 779                        0.02500     0.15800  2019
# 780                        0.03500     0.23500  2019
# 781                        0.09100     0.20200  2019
#
# [782 rows x 9 columns]

# %%
correcao_nomes = {'Hong Kong S.A.R., China':'Hong Kong',
            'North Macedonia':'Macedonia',
            'North Cyprus' :'Northern Cyprus',
            'Taiwan Province of China' : 'Taiwan',
            'Somaliland region':'Somaliland Region',
            ' Northern Cyprus': 'Northern Cyprus',
            'Trinidad & Tobago': 'Trinidad and Tobago'}

df_5_anos = df_5_anos.replace(correcao_nomes)

# %%
agrupado_por_ano = df_5_anos.groupby(by = 'Year')
agrupado_por_ano.mean().plot(ylim=(0,2.5), ylabel='Score per criterion').legend(loc='upper left')
media_variaveis_por_ano = agrupado_por_ano.mean()

display(media_variaveis_por_ano)
# Out:
#       Happiness Score  Economy (GDP per Capita)    Family  \
# Year
# 2015         5.375734                  0.846137  0.991046
# 2016         5.382185                  0.953880  0.793621
# 2017         5.354019                  0.984718  1.188898
# 2018         5.375917                  0.891449  1.213237
# 2019         5.407096                  0.905147  1.208814
#
#       Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# Year
# 2015                  0.630259  0.428615                       0.143422
# 2016                  0.557619  0.370994                       0.137624
# 2017                  0.551341  0.408786                       0.123120
# 2018                  0.597346  0.454506                       0.112000
# 2019                  0.725244  0.392571                       0.110603
#
#       Generosity
# Year
# 2015    0.237296
# 2016    0.242635
# 2017    0.246883
# 2018    0.181006
# 2019    0.184846

# %%
variacao = media_variaveis_por_ano.diff().dropna().apply(lambda x: round(x,3))
variacao.index = ['De 2015 a 2016', 'De 2016 a 2017', 'De 2017 a 2018', 'De 2018 a 2019']
variacao.T.style.format('{:.3f}').highlight_max(color='darkgreen') \
                     .highlight_min(color='#C26161')
# Out:
# <style type="text/css">
# #T_d8b9b_row0_col1, #T_d8b9b_row1_col2, #T_d8b9b_row2_col0, #T_d8b9b_row4_col3 {
#   background-color: #C26161;
# }
# #T_d8b9b_row1_col0, #T_d8b9b_row2_col1, #T_d8b9b_row3_col2, #T_d8b9b_row3_col3, #T_d8b9b_row4_col2 {
#   background-color: darkgreen;
# }
# </style>
# <table id="T_d8b9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8b9b_level0_col0" class="col_heading level0 col0" >De 2015 a 2016</th>
#       <th id="T_d8b9b_level0_col1" class="col_heading level0 col1" >De 2016 a 2017</th>
#       <th id="T_d8b9b_level0_col2" class="col_heading level0 col2" >De 2017 a 2018</th>
#       <th id="T_d8b9b_level0_col3" class="col_heading level0 col3" >De 2018 a 2019</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8b9b_level0_row0" class="row_heading level0 row0" >Happiness Score</th>
#       <td id="T_d8b9b_row0_col0" class="data row0 col0" >0.006</td>
#       <td id="T_d8b9b_row0_col1" class="data row0 col1" >-0.028</td>
#       <td id="T_d8b9b_row0_col2" class="data row0 col2" >0.022</td>
#       <td id="T_d8b9b_row0_col3" class="data row0 col3" >0.031</td>
#     </tr>
#     <tr>
#       <th id="T_d8b9b_level0_row1" class="row_heading level0 row1" >Economy (GDP per Capita)</th>
#       <td id="T_d8b9b_row1_col0" class="data row1 col0" >0.108</td>
#       <td id="T_d8b9b_row1_col1" class="data row1 col1" >0.031</td>
#       <td id="T_d8b9b_row1_col2" class="data row1 col2" >-0.093</td>
#       <td id="T_d8b9b_row1_col3" class="data row1 col3" >0.014</td>
#     </tr>
#     <tr>
#       <th id="T_d8b9b_level0_row2" class="row_heading level0 row2" >Family</th>
#       <td id="T_d8b9b_row2_col0" class="data row2 col0" >-0.197</td>
#       <td id="T_d8b9b_row2_col1" class="data row2 col1" >0.395</td>
#       <td id="T_d8b9b_row2_col2" class="data row2 col2" >0.024</td>
#       <td id="T_d8b9b_row2_col3" class="data row2 col3" >-0.004</td>
#     </tr>
#     <tr>
#       <th id="T_d8b9b_level0_row3" class="row_heading level0 row3" >Health (Life Expectancy)</th>
#       <td id="T_d8b9b_row3_col0" class="data row3 col0" >-0.073</td>
#       <td id="T_d8b9b_row3_col1" class="data row3 col1" >-0.006</td>
#       <td id="T_d8b9b_row3_col2" class="data row3 col2" >0.046</td>
#       <td id="T_d8b9b_row3_col3" class="data row3 col3" >0.128</td>
#     </tr>
#     <tr>
#       <th id="T_d8b9b_level0_row4" class="row_heading level0 row4" >Freedom</th>
#       <td id="T_d8b9b_row4_col0" class="data row4 col0" >-0.058</td>
#       <td id="T_d8b9b_row4_col1" class="data row4 col1" >0.038</td>
#       <td id="T_d8b9b_row4_col2" class="data row4 col2" >0.046</td>
#       <td id="T_d8b9b_row4_col3" class="data row4 col3" >-0.062</td>
#     </tr>
#     <tr>
#       <th id="T_d8b9b_level0_row5" class="row_heading level0 row5" >Trust (Government Corruption)</th>
#       <td id="T_d8b9b_row5_col0" class="data row5 col0" >-0.006</td>
#       <td id="T_d8b9b_row5_col1" class="data row5 col1" >-0.015</td>
#       <td id="T_d8b9b_row5_col2" class="data row5 col2" >-0.011</td>
#       <td id="T_d8b9b_row5_col3" class="data row5 col3" >-0.001</td>
#     </tr>
#     <tr>
#       <th id="T_d8b9b_level0_row6" class="row_heading level0 row6" >Generosity</th>
#       <td id="T_d8b9b_row6_col0" class="data row6 col0" >0.005</td>
#       <td id="T_d8b9b_row6_col1" class="data row6 col1" >0.004</td>
#       <td id="T_d8b9b_row6_col2" class="data row6 col2" >-0.066</td>
#       <td id="T_d8b9b_row6_col3" class="data row6 col3" >0.004</td>
#     </tr>
#   </tbody>
# </table>

# %%
variacao_percentual = (media_variaveis_por_ano.pct_change().dropna() * 100).apply(lambda x: round(x,2))
variacao_percentual.index = ['De 2015 a 2016 [%]', 'De 2016 a 2017 [%]', 'De 2017 a 2018 [%]', 'De 2018 a 2019 [%]']
variacao_percentual.T.style.format('{:.2f}%').highlight_max(color='darkgreen') \
                     .highlight_min(color='#C26161')
# Out:
# <style type="text/css">
# #T_bc7ef_row1_col0, #T_bc7ef_row2_col1, #T_bc7ef_row3_col3, #T_bc7ef_row4_col2 {
#   background-color: darkgreen;
# }
# #T_bc7ef_row2_col0, #T_bc7ef_row4_col3, #T_bc7ef_row5_col1, #T_bc7ef_row6_col2 {
#   background-color: #C26161;
# }
# </style>
# <table id="T_bc7ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc7ef_level0_col0" class="col_heading level0 col0" >De 2015 a 2016 [%]</th>
#       <th id="T_bc7ef_level0_col1" class="col_heading level0 col1" >De 2016 a 2017 [%]</th>
#       <th id="T_bc7ef_level0_col2" class="col_heading level0 col2" >De 2017 a 2018 [%]</th>
#       <th id="T_bc7ef_level0_col3" class="col_heading level0 col3" >De 2018 a 2019 [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc7ef_level0_row0" class="row_heading level0 row0" >Happiness Score</th>
#       <td id="T_bc7ef_row0_col0" class="data row0 col0" >0.12%</td>
#       <td id="T_bc7ef_row0_col1" class="data row0 col1" >-0.52%</td>
#       <td id="T_bc7ef_row0_col2" class="data row0 col2" >0.41%</td>
#       <td id="T_bc7ef_row0_col3" class="data row0 col3" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_bc7ef_level0_row1" class="row_heading level0 row1" >Economy (GDP per Capita)</th>
#       <td id="T_bc7ef_row1_col0" class="data row1 col0" >12.73%</td>
#       <td id="T_bc7ef_row1_col1" class="data row1 col1" >3.23%</td>
#       <td id="T_bc7ef_row1_col2" class="data row1 col2" >-9.47%</td>
#       <td id="T_bc7ef_row1_col3" class="data row1 col3" >1.54%</td>
#     </tr>
#     <tr>
#       <th id="T_bc7ef_level0_row2" class="row_heading level0 row2" >Family</th>
#       <td id="T_bc7ef_row2_col0" class="data row2 col0" >-19.92%</td>
#       <td id="T_bc7ef_row2_col1" class="data row2 col1" >49.81%</td>
#       <td id="T_bc7ef_row2_col2" class="data row2 col2" >2.05%</td>
#       <td id="T_bc7ef_row2_col3" class="data row2 col3" >-0.36%</td>
#     </tr>
#     <tr>
#       <th id="T_bc7ef_level0_row3" class="row_heading level0 row3" >Health (Life Expectancy)</th>
#       <td id="T_bc7ef_row3_col0" class="data row3 col0" >-11.53%</td>
#       <td id="T_bc7ef_row3_col1" class="data row3 col1" >-1.13%</td>
#       <td id="T_bc7ef_row3_col2" class="data row3 col2" >8.34%</td>
#       <td id="T_bc7ef_row3_col3" class="data row3 col3" >21.41%</td>
#     </tr>
#     <tr>
#       <th id="T_bc7ef_level0_row4" class="row_heading level0 row4" >Freedom</th>
#       <td id="T_bc7ef_row4_col0" class="data row4 col0" >-13.44%</td>
#       <td id="T_bc7ef_row4_col1" class="data row4 col1" >10.19%</td>
#       <td id="T_bc7ef_row4_col2" class="data row4 col2" >11.18%</td>
#       <td id="T_bc7ef_row4_col3" class="data row4 col3" >-13.63%</td>
#     </tr>
#     <tr>
#       <th id="T_bc7ef_level0_row5" class="row_heading level0 row5" >Trust (Government Corruption)</th>
#       <td id="T_bc7ef_row5_col0" class="data row5 col0" >-4.04%</td>
#       <td id="T_bc7ef_row5_col1" class="data row5 col1" >-10.54%</td>
#       <td id="T_bc7ef_row5_col2" class="data row5 col2" >-9.03%</td>
#       <td id="T_bc7ef_row5_col3" class="data row5 col3" >-1.25%</td>
#     </tr>
#     <tr>
#       <th id="T_bc7ef_level0_row6" class="row_heading level0 row6" >Generosity</th>
#       <td id="T_bc7ef_row6_col0" class="data row6 col0" >2.25%</td>
#       <td id="T_bc7ef_row6_col1" class="data row6 col1" >1.75%</td>
#       <td id="T_bc7ef_row6_col2" class="data row6 col2" >-26.68%</td>
#       <td id="T_bc7ef_row6_col3" class="data row6 col3" >2.12%</td>
#     </tr>
#   </tbody>
# </table>

# %%
media_variaveis_por_ano.describe().drop(index=['count', '25%', '50%', '75%'])
# Out:
#       Happiness Score  Economy (GDP per Capita)    Family  \
# mean         5.378990                  0.916266  1.079123
# std          0.018998                  0.054217  0.184476
# min          5.354019                  0.846137  0.793621
# max          5.407096                  0.984718  1.213237
#
#       Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# mean                  0.612362  0.411094                       0.125354
# std                   0.070726  0.032203                       0.014815
# min                   0.551341  0.370994                       0.110603
# max                   0.725244  0.454506                       0.143422
#
#       Generosity
# mean    0.218533
# std     0.032710
# min     0.181006
# max     0.246883

# %% [markdown]
# ## 3. Quais foram os top 3 países que mais tiveram mudança positiva e negativa de GPD. ✅❌

# %% [markdown]
# Abaixo são feitas as seguintes ações:
#
# Reorganiza-se o dataframe de 5 anos para mostrar apenas o valor do GDP por ano e por país;\
# Calcula-se a variação do GDP de ano a ano e depois de 2015 a 2019;\
# Obtém-se os três maiores e menores aumentos (podendo ser diminuição) do GDP;\
# Organiza-se os resultados acima em df por ano;\
# Apresenta-se as variações de 2015 a 2019

# %%
geral_GPD = df_5_anos.pivot_table(
    values = 'Economy (GDP per Capita)',
    index = ['Year'],
    columns = ['Country'],
    fill_value = np.nan,
    dropna = False,
    aggfunc = 'mean'
)
geral_GPD
# Out:
# Country  Afghanistan   Albania   Algeria    Angola  Argentina   Armenia  \
# Year
# 2015        0.319820  0.878670  0.939290  0.757780   1.053510  0.768210
# 2016        0.382270  0.955300  1.052660  0.847310   1.151370  0.860860
# 2017        0.401477  0.996193  1.091864  0.858428   1.185295  0.900597
# 2018        0.332000  0.916000  0.979000  0.730000   1.073000  0.816000
# 2019        0.350000  0.947000  1.002000       NaN   1.092000  0.850000
#
# Country  Australia   Austria  Azerbaijan   Bahrain  ...  United Arab Emirates  \
# Year                                                ...
# 2015      1.333580  1.337230    1.023890  1.323760  ...              1.427270
# 2016      1.444430  1.450380    1.123730  1.440240  ...              1.573520
# 2017      1.484415  1.487097    1.153602  1.488412  ...              1.626343
# 2018      1.340000  1.341000    1.024000  1.338000  ...              2.096000
# 2019      1.372000  1.376000    1.043000  1.362000  ...              1.503000
#
# Country  United Kingdom  United States  Uruguay  Uzbekistan  Venezuela  \
# Year
# 2015           1.266370       1.394510  1.06166    0.632440   1.044240
# 2016           1.402830       1.507960  1.18157    0.735910   1.133670
# 2017           1.441634       1.546259  1.21756    0.786441   1.128431
# 2018           1.244000       1.398000  1.09300    0.719000   0.996000
# 2019           1.333000       1.433000  1.12400    0.745000   0.960000
#
# Country   Vietnam     Yemen    Zambia  Zimbabwe
# Year
# 2015     0.632160  0.546490  0.470380  0.271000
# 2016     0.740370  0.579390  0.612020  0.350410
# 2017     0.788548  0.591683  0.636407  0.375847
# 2018     0.715000  0.442000  0.562000  0.357000
# 2019     0.741000  0.287000  0.578000  0.366000
#
# [5 rows x 164 columns]

# %%
variacao_GPD = geral_GPD.diff().iloc[1:,:].T
top_3_positivo_15_16 = variacao_GPD['2016'].nlargest(3)
top_3_negativo_15_16 = variacao_GPD['2016'].nsmallest(3)
top_3_positivo_16_17 = variacao_GPD['2017'].nlargest(3)
top_3_negativo_16_17 = variacao_GPD['2017'].nsmallest(3)
top_3_positivo_17_18 = variacao_GPD['2018'].nlargest(3)
top_3_negativo_17_18 = variacao_GPD['2018'].nsmallest(3)
top_3_positivo_18_19 = variacao_GPD['2019'].nlargest(3)
top_3_negativo_18_19 = variacao_GPD['2019'].nsmallest(3)

# %%
top_3_15_16 = pd.concat([top_3_positivo_15_16.reset_index(),top_3_negativo_15_16.reset_index()],axis=1)
top_3_15_16.columns = ['Country',f'Greatest GPD variations','Country','Lowest GPD variations']
print('Resultados de 2015 a 2016')
display(top_3_15_16)

top_3_16_17 = pd.concat([top_3_positivo_16_17.reset_index(),top_3_negativo_16_17.reset_index()],axis=1)
top_3_16_17.columns = ['Country',f'Greatest GPD variations','Country','Lowest GPD variations']
print('Resultados de 2016 a 2017')
display(top_3_16_17)

top_3_17_18 = pd.concat([top_3_positivo_17_18.reset_index(),top_3_negativo_17_18.reset_index()],axis=1)
top_3_17_18.columns = ['Country',f'Greatest GPD variations','Country','Lowest GPD variations']
print('Resultados de 2017 a 2018')
display(top_3_17_18)

top_3_18_19 = pd.concat([top_3_positivo_18_19.reset_index(),top_3_negativo_18_19.reset_index()],axis=1)
top_3_18_19.columns = ['Country',f'Greatest GPD variations','Country','Lowest GPD variations']
print('Resultados de 2018 a 2019')
display(top_3_18_19)
# Out:
# Resultados de 2015 a 2016
#       Country  Greatest GPD variations       Country  Lowest GPD variations
# 0    Tanzania                  0.18635         Libya               -0.06457
# 1    Mongolia                  0.16034         Yemen                0.03290
# 2  Mauritania                  0.15984  Sierra Leone                0.03461
# Resultados de 2016 a 2017
#    Country  Greatest GPD variations    Country  Lowest GPD variations
# 0     Mali                 0.163260    Lebanon              -0.047692
# 1   Malawi                 0.146352     Jordan              -0.005718
# 2  Georgia                 0.112693  Venezuela              -0.005239
# Resultados de 2017 a 2018
#                 Country  Greatest GPD variations         Country  \
# 0  United Arab Emirates                 0.469657           Qatar
# 1               Myanmar                 0.314889  United Kingdom
# 2                Guinea                 0.099450          Jordan
#
#    Lowest GPD variations
# 0              -0.221766
# 1              -0.197634
# 2              -0.169012
# Resultados de 2018 a 2019
#           Country  Greatest GPD variations               Country  \
# 0  United Kingdom                    0.089  United Arab Emirates
# 1        Malaysia                    0.060                 Yemen
# 2           Libya                    0.059                 Syria
#
#    Lowest GPD variations
# 0                 -0.593
# 1                 -0.155
# 2                 -0.070

# %%
variacao_GPD = geral_GPD.diff(periods = 4).iloc[4:,:].T
variacao_GPD.dropna().sort_values(by = '2019',ascending = False).iloc[[0,1,2,-3,-2,-1]].style.highlight_max(color='darkgreen') \
                     .highlight_min(color='#C26161')
# Out:
# <style type="text/css">
# #T_f6a69_row0_col0 {
#   background-color: darkgreen;
# }
# #T_f6a69_row5_col0 {
#   background-color: #C26161;
# }
# </style>
# <table id="T_f6a69">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th id="T_f6a69_level0_col0" class="col_heading level0 col0" >2019</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6a69_level0_row0" class="row_heading level0 row0" >Myanmar</th>
#       <td id="T_f6a69_row0_col0" class="data row0 col0" >0.438920</td>
#     </tr>
#     <tr>
#       <th id="T_f6a69_level0_row1" class="row_heading level0 row1" >Guinea</th>
#       <td id="T_f6a69_row1_col0" class="data row1 col0" >0.205830</td>
#     </tr>
#     <tr>
#       <th id="T_f6a69_level0_row2" class="row_heading level0 row2" >Tanzania</th>
#       <td id="T_f6a69_row2_col0" class="data row2 col0" >0.190800</td>
#     </tr>
#     <tr>
#       <th id="T_f6a69_level0_row3" class="row_heading level0 row3" >Venezuela</th>
#       <td id="T_f6a69_row3_col0" class="data row3 col0" >-0.084240</td>
#     </tr>
#     <tr>
#       <th id="T_f6a69_level0_row4" class="row_heading level0 row4" >Libya</th>
#       <td id="T_f6a69_row4_col0" class="data row4 col0" >-0.087450</td>
#     </tr>
#     <tr>
#       <th id="T_f6a69_level0_row5" class="row_heading level0 row5" >Yemen</th>
#       <td id="T_f6a69_row5_col0" class="data row5 col0" >-0.259490</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4. Qual foi o país que mais subiu no ranking no período inteiro analisado. 📈

# %% [markdown]
# Abaixo são feitas as seguintes ações:
#
# Cria-se df separados por ano e com a variável de interesse;\
# Une-se os df e cria-se a coluna com a variação do índice;\
# Calcula-se e apresenta-se as maiores variações (quem mais subiu e mais desceu no ranking)

# %%
ranking_2015 = df_2015[['Country','Happiness Rank']]
ranking_2019 = df_2019[['Country or region','Overall rank']]
ranking_2015.columns = ['Country','Happiness Rank 2015']
ranking_2019.columns = ['Country','Happiness Rank 2019']
ranking_2015_2019 = pd.merge(left = ranking_2015, right = ranking_2019, left_on = 'Country' , right_on = 'Country')
ranking_2015_2019['Diff'] = ranking_2015_2019['Happiness Rank 2015'] - ranking_2015_2019['Happiness Rank 2019']
melhor_resultado_ranking = ranking_2015_2019.nlargest(1, 'Diff')
pior_resultado_ranking = ranking_2015_2019.nsmallest(1, 'Diff')
print('País que mais subiu no ranking, considerando os valores de 2015 e 2019:')
display(melhor_resultado_ranking)
print('País que mais desceu no ranking, considerando os valores de 2015 e 2019:')
display(pior_resultado_ranking)
# Out:
# País que mais subiu no ranking, considerando os valores de 2015 e 2019:
#     Country  Happiness Rank 2015  Happiness Rank 2019  Diff
# 145   Benin                  155                  102    53
# País que mais desceu no ranking, considerando os valores de 2015 e 2019:
#       Country  Happiness Rank 2015  Happiness Rank 2019  Diff
# 21  Venezuela                   23                  108   -85

# %% [markdown]
# ## 5. Teve países que saíram ou entraram do index. ❓

# %% [markdown]
# Abaixo são feitas as seguintes ações:
#
# Cria-se uma series contendo apenas a coluna com os países da base de dados;\
# Apresenta-se apenas aqueles que não tem 5 aparições, logo mostra-se os que entraram e saíram

# %%
entraram_ou_sairam = df_5_anos['Country'].value_counts()
entraram_ou_sairam.where(entraram_ou_sairam < 5).dropna()
# Out:
# Laos                        4.0
# Sudan                       4.0
# South Sudan                 4.0
# Central African Republic    4.0
# Lesotho                     4.0
# Mozambique                  4.0
# Namibia                     4.0
# Angola                      4.0
# Somalia                     4.0
# Belize                      3.0
# Comoros                     3.0
# Somaliland Region           2.0
# Suriname                    2.0
# Swaziland                   2.0
# Puerto Rico                 1.0
# Oman                        1.0
# Djibouti                    1.0
# Gambia                      1.0
# Name: Country, dtype: float64

# %% [markdown]
# ## 6. Quais foram os 3 países que mais tiveram mudança na expectativa de vida, positiva e negativa. ✅❌

# %% [markdown]
# Abaixo são feitas as seguintes ações:
#
# Cria-se um df reorganizando o df geral para conter apenas os valores da expectativa de vida, países e anos;\
# Cria-se diversos dfs contendo as variações das expectativas de vida e os top 3 (maiores variações, tanto positiva quanto negativa) ano a ano;\
# Apresenta-se as variações de 2015 a 2019

# %%
geral_LifeExpectancy = df_5_anos.pivot_table(
    values = 'Health (Life Expectancy)',
    index = ['Year'],
    columns = ['Country'],
    fill_value = np.nan,
    dropna = False,
    aggfunc = 'mean'
)
geral_LifeExpectancy
# Out:
# Country  Afghanistan  Albania   Algeria    Angola  Argentina   Armenia  \
# Year
# 2015        0.303350  0.81325  0.617660  0.166830   0.787230  0.729900
# 2016        0.173440  0.73007  0.618040  0.049910   0.697110  0.640830
# 2017        0.180747  0.73116  0.617585  0.049869   0.695137  0.637524
# 2018        0.255000  0.79000  0.687000  0.269000   0.744000  0.666000
# 2019        0.361000  0.87400  0.785000       NaN   0.881000  0.815000
#
# Country  Australia   Austria  Azerbaijan   Bahrain  ...  United Arab Emirates  \
# Year                                                ...
# 2015      0.931560  0.890420    0.640450  0.747160  ...              0.809250
# 2016      0.851200  0.805650    0.545040  0.656960  ...              0.729930
# 2017      0.843887  0.815328    0.540776  0.653133  ...              0.726798
# 2018      0.910000  0.891000    0.603000  0.698000  ...              0.670000
# 2019      1.036000  1.016000    0.769000  0.871000  ...              0.825000
#
# Country  United Kingdom  United States   Uruguay  Uzbekistan  Venezuela  \
# Year
# 2015           0.909430       0.861790  0.811600    0.597720   0.720520
# 2016           0.809910       0.779000  0.721830    0.501630   0.619040
# 2017           0.805336       0.774287  0.719217    0.498273   0.617144
# 2018           0.888000       0.819000  0.771000    0.605000   0.657000
# 2019           0.996000       0.874000  0.891000    0.756000   0.805000
#
# Country   Vietnam     Yemen    Zambia  Zimbabwe
# Year
# 2015     0.746760  0.400640  0.299240  0.334750
# 2016     0.661570  0.310480  0.235730  0.159500
# 2017     0.652169  0.310081  0.257836  0.196764
# 2018     0.702000  0.343000  0.295000  0.248000
# 2019     0.851000  0.463000  0.426000  0.433000
#
# [5 rows x 164 columns]

# %%
variacao_LifeExpectancy = geral_LifeExpectancy.diff().iloc[1:,:].T
top_3_positivo_15_16 = variacao_LifeExpectancy['2016'].nlargest(3)
top_3_negativo_15_16 = variacao_LifeExpectancy['2016'].nsmallest(3)
top_3_positivo_16_17 = variacao_LifeExpectancy['2017'].nlargest(3)
top_3_negativo_16_17 = variacao_LifeExpectancy['2017'].nsmallest(3)
top_3_positivo_17_18 = variacao_LifeExpectancy['2018'].nlargest(3)
top_3_negativo_17_18 = variacao_LifeExpectancy['2018'].nsmallest(3)
top_3_positivo_18_19 = variacao_LifeExpectancy['2019'].nlargest(3)
top_3_negativo_18_19 = variacao_LifeExpectancy['2019'].nsmallest(3)

# %%
top_3_15_16 = pd.concat([top_3_positivo_15_16.reset_index(),top_3_negativo_15_16.reset_index()],axis=1)
top_3_15_16.columns = ['Country',f'Greatest life expectancy variations','Country','Lowest life expectancy variations']
print('Resultados de 2015 a 2016')
display(top_3_15_16)

top_3_16_17 = pd.concat([top_3_positivo_16_17.reset_index(),top_3_negativo_16_17.reset_index()],axis=1)
top_3_16_17.columns = ['Country',f'Greatest life expectancy variations','Country','Lowest life expectancy variations']
print('Resultados de 2016 a 2017')
display(top_3_16_17)

top_3_17_18 = pd.concat([top_3_positivo_17_18.reset_index(),top_3_negativo_17_18.reset_index()],axis=1)
top_3_17_18.columns = ['Country',f'Greatest life expectancy variations','Country','Lowest life expectancy variations']
print('Resultados de 2017 a 2018')
display(top_3_17_18)

top_3_18_19 = pd.concat([top_3_positivo_18_19.reset_index(),top_3_negativo_18_19.reset_index()],axis=1)
top_3_18_19.columns = ['Country',f'Greatest life expectancy variations','Country','Lowest life expectancy variations']
print('Resultados de 2018 a 2019')
display(top_3_18_19)
# Out:
# Resultados de 2015 a 2016
#             Country  Greatest life expectancy variations   Country  \
# 0          Botswana                              0.29976  Cambodia
# 1  Congo (Kinshasa)                              0.08994     Libya
# 2            Malawi                              0.06802  Zimbabwe
#
#    Lowest life expectancy variations
# 0                           -0.18620
# 1                           -0.18076
# 2                           -0.17525
# Resultados de 2016 a 2017
#     Country  Greatest life expectancy variations  Country  \
# 0   Moldova                             0.066375    Syria
# 1   Jamaica                             0.046332   Russia
# 2  Zimbabwe                             0.037264  Iceland
#
#    Lowest life expectancy variations
# 0                          -0.129407
# 1                          -0.042561
# 2                          -0.033778
# Resultados de 2017 a 2018
#         Country  Greatest life expectancy variations               Country  \
# 0        Angola                             0.219131  United Arab Emirates
# 1         Kenya                             0.144012                 Niger
# 2  South Africa                             0.142920                  Mali
#
#    Lowest life expectancy variations
# 0                          -0.056798
# 1                          -0.047505
# 2                          -0.017366
# Resultados de 2018 a 2019
#         Country  Greatest life expectancy variations  Country  \
# 0  Sierra Leone                                0.242    Syria
# 1       Burundi                                0.235  Lebanon
# 2    Mozambique                                0.217     Iraq
#
#    Lowest life expectancy variations
# 0                             -0.099
# 1                              0.030
# 2                              0.038

# %%
variacao_LifeExpectancy = geral_LifeExpectancy.diff(periods = 4).iloc[4:,:].T
variacao_LifeExpectancy.dropna().sort_values(by = '2019',ascending = False).iloc[[0,1,2,-3,-2,-1]].style.highlight_max(color='darkgreen') \
                     .highlight_min(color='#C26161')
# Out:
# <style type="text/css">
# #T_be745_row0_col0 {
#   background-color: darkgreen;
# }
# #T_be745_row5_col0 {
#   background-color: #C26161;
# }
# </style>
# <table id="T_be745">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th id="T_be745_level0_col0" class="col_heading level0 col0" >2019</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be745_level0_row0" class="row_heading level0 row0" >Botswana</th>
#       <td id="T_be745_row0_col0" class="data row0 col0" >0.490240</td>
#     </tr>
#     <tr>
#       <th id="T_be745_level0_row1" class="row_heading level0 row1" >Mozambique</th>
#       <td id="T_be745_row1_col0" class="data row1 col0" >0.298690</td>
#     </tr>
#     <tr>
#       <th id="T_be745_level0_row2" class="row_heading level0 row2" >Malawi</th>
#       <td id="T_be745_row2_col0" class="data row2 col0" >0.269380</td>
#     </tr>
#     <tr>
#       <th id="T_be745_level0_row3" class="row_heading level0 row3" >Libya</th>
#       <td id="T_be745_row3_col0" class="data row3 col0" >-0.030800</td>
#     </tr>
#     <tr>
#       <th id="T_be745_level0_row4" class="row_heading level0 row4" >Swaziland</th>
#       <td id="T_be745_row4_col0" class="data row4 col0" >-0.075660</td>
#     </tr>
#     <tr>
#       <th id="T_be745_level0_row5" class="row_heading level0 row5" >Syria</th>
#       <td id="T_be745_row5_col0" class="data row5 col0" >-0.281930</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 7. Até 2 questões extras que vocês acham interessante analisar.

# %% [markdown]
# ### 7. Quais são os indicadores que mais influenciam no índice de felicidade?

# %%
pd.DataFrame(df_5_anos.corr()['Happiness Score']).sort_values('Happiness Score', ascending = False).iloc[1:].style.highlight_max(color='darkgreen') \
                     .highlight_min(color='#C26161')
# Out:
# <style type="text/css">
# #T_4a3cd_row0_col0 {
#   background-color: darkgreen;
# }
# #T_4a3cd_row5_col0 {
#   background-color: #C26161;
# }
# </style>
# <table id="T_4a3cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a3cd_level0_col0" class="col_heading level0 col0" >Happiness Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a3cd_level0_row0" class="row_heading level0 row0" >Economy (GDP per Capita)</th>
#       <td id="T_4a3cd_row0_col0" class="data row0 col0" >0.789284</td>
#     </tr>
#     <tr>
#       <th id="T_4a3cd_level0_row1" class="row_heading level0 row1" >Health (Life Expectancy)</th>
#       <td id="T_4a3cd_row1_col0" class="data row1 col0" >0.742456</td>
#     </tr>
#     <tr>
#       <th id="T_4a3cd_level0_row2" class="row_heading level0 row2" >Family</th>
#       <td id="T_4a3cd_row2_col0" class="data row2 col0" >0.648799</td>
#     </tr>
#     <tr>
#       <th id="T_4a3cd_level0_row3" class="row_heading level0 row3" >Freedom</th>
#       <td id="T_4a3cd_row3_col0" class="data row3 col0" >0.551258</td>
#     </tr>
#     <tr>
#       <th id="T_4a3cd_level0_row4" class="row_heading level0 row4" >Trust (Government Corruption)</th>
#       <td id="T_4a3cd_row4_col0" class="data row4 col0" >0.398418</td>
#     </tr>
#     <tr>
#       <th id="T_4a3cd_level0_row5" class="row_heading level0 row5" >Generosity</th>
#       <td id="T_4a3cd_row5_col0" class="data row5 col0" >0.137578</td>
#     </tr>
#   </tbody>
# </table>

# %%
media_por_pais = df_5_anos.groupby(by = 'Country').mean()
media_por_pais
# Out:
#              Happiness Score  Economy (GDP per Capita)    Family  \
# Country
# Afghanistan          3.51280                  0.357113  0.409753
# Albania              4.71260                  0.938633  0.754931
# Algeria              5.66760                  1.012963  1.074205
# Angola               3.87225                  0.798380  0.938368
# Argentina            6.45940                  1.111035  1.330960
# ...                      ...                       ...       ...
# Venezuela            5.53140                  1.052468  1.323264
# Vietnam              5.15460                  0.723416  1.138384
# Yemen                3.62580                  0.489313  0.865448
# Zambia               4.58440                  0.571761  0.932381
# Zimbabwe             4.00660                  0.344051  1.007727
#
#              Health (Life Expectancy)   Freedom  \
# Country
# Afghanistan                  0.254707  0.117924
# Albania                      0.787696  0.371898
# Algeria                      0.665057  0.178437
# Angola                       0.133902  0.027433
# Argentina                    0.760895  0.481620
# ...                               ...       ...
# Venezuela                    0.683741  0.213709
# Vietnam                      0.722700  0.577207
# Yemen                        0.365440  0.244175
# Zambia                       0.302761  0.462099
# Zimbabwe                     0.274403  0.323257
#
#              Trust (Government Corruption)  Generosity
# Country
# Afghanistan                       0.058094    0.267730
# Albania                           0.043201    0.167887
# Algeria                           0.146099    0.069219
# Angola                            0.071570    0.105269
# Argentina                         0.064308    0.092371
# ...                                    ...         ...
# Venezuela                         0.071444    0.057186
# Vietnam                           0.091921    0.195664
# Yemen                             0.067045    0.096929
# Zambia                            0.097337    0.218430
# Zimbabwe                          0.089997    0.169409
#
# [164 rows x 7 columns]

# %%
media_por_pais = pd.merge(left = media_por_pais,
         right = df_2016[['Country', 'Region']],
         on = 'Country')
media_por_pais.head()
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)    Family  \
# 0  Afghanistan          3.51280                  0.357113  0.409753
# 1      Albania          4.71260                  0.938633  0.754931
# 2      Algeria          5.66760                  1.012963  1.074205
# 3       Angola          3.87225                  0.798380  0.938368
# 4    Argentina          6.45940                  1.111035  1.330960
#
#    Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                  0.254707  0.117924                       0.058094
# 1                  0.787696  0.371898                       0.043201
# 2                  0.665057  0.178437                       0.146099
# 3                  0.133902  0.027433                       0.071570
# 4                  0.760895  0.481620                       0.064308
#
#    Generosity                           Region
# 0    0.267730                    Southern Asia
# 1    0.167887       Central and Eastern Europe
# 2    0.069219  Middle East and Northern Africa
# 3    0.105269               Sub-Saharan Africa
# 4    0.092371      Latin America and Caribbean

# %%
media_por_pais.isna().sum()
# Out:
# Country                          0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Region                           0
# dtype: int64

# %%
print(media_por_pais['Region'].nunique())
media_por_pais['Region'].unique()
# Out:
# 10
# array(['Southern Asia', 'Central and Eastern Europe',
#        'Middle East and Northern Africa', 'Sub-Saharan Africa',
#        'Latin America and Caribbean', 'Australia and New Zealand',
#        'Western Europe', 'Southeastern Asia', 'North America',
#        'Eastern Asia'], dtype=object)

# %%
media_por_regiao = media_por_pais.groupby(by = 'Region').mean()
# media_por_regiao = pd.DataFrame(media_por_regiao['Happiness Score'].sort_values(ascending = False))
media_por_regiao = pd.DataFrame(media_por_regiao.sort_values(ascending = False, by='Happiness Score'))
media_por_regiao.style.format('{:.3f}').highlight_max(color='darkgreen') \
                     .highlight_min(color='#C26161')
# Out:
# <style type="text/css">
# #T_4a73d_row0_col0, #T_4a73d_row0_col2, #T_4a73d_row0_col3, #T_4a73d_row0_col4, #T_4a73d_row0_col5, #T_4a73d_row0_col6, #T_4a73d_row1_col1 {
#   background-color: darkgreen;
# }
# #T_4a73d_row5_col5, #T_4a73d_row5_col6, #T_4a73d_row7_col4, #T_4a73d_row8_col2, #T_4a73d_row9_col0, #T_4a73d_row9_col1, #T_4a73d_row9_col3 {
#   background-color: #C26161;
# }
# </style>
# <table id="T_4a73d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a73d_level0_col0" class="col_heading level0 col0" >Happiness Score</th>
#       <th id="T_4a73d_level0_col1" class="col_heading level0 col1" >Economy (GDP per Capita)</th>
#       <th id="T_4a73d_level0_col2" class="col_heading level0 col2" >Family</th>
#       <th id="T_4a73d_level0_col3" class="col_heading level0 col3" >Health (Life Expectancy)</th>
#       <th id="T_4a73d_level0_col4" class="col_heading level0 col4" >Freedom</th>
#       <th id="T_4a73d_level0_col5" class="col_heading level0 col5" >Trust (Government Corruption)</th>
#       <th id="T_4a73d_level0_col6" class="col_heading level0 col6" >Generosity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a73d_level0_row0" class="row_heading level0 row0" >Australia and New Zealand</th>
#       <td id="T_4a73d_row0_col0" class="data row0 col0" >7.295</td>
#       <td id="T_4a73d_row0_col1" class="data row0 col1" >1.356</td>
#       <td id="T_4a73d_row0_col2" class="data row0 col2" >1.424</td>
#       <td id="T_4a73d_row0_col3" class="data row0 col3" >0.903</td>
#       <td id="T_4a73d_row0_col4" class="data row0 col4" >0.611</td>
#       <td id="T_4a73d_row0_col5" class="data row0 col5" >0.357</td>
#       <td id="T_4a73d_row0_col6" class="data row0 col6" >0.424</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row1" class="row_heading level0 row1" >North America</th>
#       <td id="T_4a73d_row1_col0" class="data row1 col0" >7.175</td>
#       <td id="T_4a73d_row1_col1" class="data row1 col1" >1.422</td>
#       <td id="T_4a73d_row1_col2" class="data row1 col2" >1.358</td>
#       <td id="T_4a73d_row1_col3" class="data row1 col3" >0.861</td>
#       <td id="T_4a73d_row1_col4" class="data row1 col4" >0.559</td>
#       <td id="T_4a73d_row1_col5" class="data row1 col5" >0.223</td>
#       <td id="T_4a73d_row1_col6" class="data row1 col6" >0.372</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row2" class="row_heading level0 row2" >Western Europe</th>
#       <td id="T_4a73d_row2_col0" class="data row2 col0" >6.789</td>
#       <td id="T_4a73d_row2_col1" class="data row2 col1" >1.375</td>
#       <td id="T_4a73d_row2_col2" class="data row2 col2" >1.348</td>
#       <td id="T_4a73d_row2_col3" class="data row2 col3" >0.893</td>
#       <td id="T_4a73d_row2_col4" class="data row2 col4" >0.518</td>
#       <td id="T_4a73d_row2_col5" class="data row2 col5" >0.226</td>
#       <td id="T_4a73d_row2_col6" class="data row2 col6" >0.272</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row3" class="row_heading level0 row3" >Latin America and Caribbean</th>
#       <td id="T_4a73d_row3_col0" class="data row3 col0" >6.063</td>
#       <td id="T_4a73d_row3_col1" class="data row3 col1" >0.957</td>
#       <td id="T_4a73d_row3_col2" class="data row3 col2" >1.172</td>
#       <td id="T_4a73d_row3_col3" class="data row3 col3" >0.673</td>
#       <td id="T_4a73d_row3_col4" class="data row3 col4" >0.468</td>
#       <td id="T_4a73d_row3_col5" class="data row3 col5" >0.095</td>
#       <td id="T_4a73d_row3_col6" class="data row3 col6" >0.187</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row4" class="row_heading level0 row4" >Eastern Asia</th>
#       <td id="T_4a73d_row4_col0" class="data row4 col0" >5.652</td>
#       <td id="T_4a73d_row4_col1" class="data row4 col1" >1.238</td>
#       <td id="T_4a73d_row4_col2" class="data row4 col2" >1.199</td>
#       <td id="T_4a73d_row4_col3" class="data row4 col3" >0.863</td>
#       <td id="T_4a73d_row4_col4" class="data row4 col4" >0.418</td>
#       <td id="T_4a73d_row4_col5" class="data row4 col5" >0.118</td>
#       <td id="T_4a73d_row4_col6" class="data row4 col6" >0.200</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row5" class="row_heading level0 row5" >Central and Eastern Europe</th>
#       <td id="T_4a73d_row5_col0" class="data row5 col0" >5.428</td>
#       <td id="T_4a73d_row5_col1" class="data row5 col1" >1.018</td>
#       <td id="T_4a73d_row5_col2" class="data row5 col2" >1.172</td>
#       <td id="T_4a73d_row5_col3" class="data row5 col3" >0.697</td>
#       <td id="T_4a73d_row5_col4" class="data row5 col4" >0.352</td>
#       <td id="T_4a73d_row5_col5" class="data row5 col5" >0.076</td>
#       <td id="T_4a73d_row5_col6" class="data row5 col6" >0.157</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row6" class="row_heading level0 row6" >Southeastern Asia</th>
#       <td id="T_4a73d_row6_col0" class="data row6 col0" >5.323</td>
#       <td id="T_4a73d_row6_col1" class="data row6 col1" >0.889</td>
#       <td id="T_4a73d_row6_col2" class="data row6 col2" >1.088</td>
#       <td id="T_4a73d_row6_col3" class="data row6 col3" >0.632</td>
#       <td id="T_4a73d_row6_col4" class="data row6 col4" >0.544</td>
#       <td id="T_4a73d_row6_col5" class="data row6 col5" >0.138</td>
#       <td id="T_4a73d_row6_col6" class="data row6 col6" >0.383</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row7" class="row_heading level0 row7" >Middle East and Northern Africa</th>
#       <td id="T_4a73d_row7_col0" class="data row7 col0" >5.321</td>
#       <td id="T_4a73d_row7_col1" class="data row7 col1" >1.100</td>
#       <td id="T_4a73d_row7_col2" class="data row7 col2" >0.993</td>
#       <td id="T_4a73d_row7_col3" class="data row7 col3" >0.665</td>
#       <td id="T_4a73d_row7_col4" class="data row7 col4" >0.346</td>
#       <td id="T_4a73d_row7_col5" class="data row7 col5" >0.145</td>
#       <td id="T_4a73d_row7_col6" class="data row7 col6" >0.178</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row8" class="row_heading level0 row8" >Southern Asia</th>
#       <td id="T_4a73d_row8_col0" class="data row8 col0" >4.581</td>
#       <td id="T_4a73d_row8_col1" class="data row8 col1" >0.639</td>
#       <td id="T_4a73d_row8_col2" class="data row8 col2" >0.804</td>
#       <td id="T_4a73d_row8_col3" class="data row8 col3" >0.513</td>
#       <td id="T_4a73d_row8_col4" class="data row8 col4" >0.393</td>
#       <td id="T_4a73d_row8_col5" class="data row8 col5" >0.100</td>
#       <td id="T_4a73d_row8_col6" class="data row8 col6" >0.301</td>
#     </tr>
#     <tr>
#       <th id="T_4a73d_level0_row9" class="row_heading level0 row9" >Sub-Saharan Africa</th>
#       <td id="T_4a73d_row9_col0" class="data row9 col0" >4.212</td>
#       <td id="T_4a73d_row9_col1" class="data row9 col1" >0.456</td>
#       <td id="T_4a73d_row9_col2" class="data row9 col2" >0.852</td>
#       <td id="T_4a73d_row9_col3" class="data row9 col3" >0.298</td>
#       <td id="T_4a73d_row9_col4" class="data row9 col4" >0.348</td>
#       <td id="T_4a73d_row9_col5" class="data row9 col5" >0.110</td>
#       <td id="T_4a73d_row9_col6" class="data row9 col6" >0.212</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.DataFrame(media_por_regiao['Happiness Score'])
# Out:
#                                  Happiness Score
# Region
# Australia and New Zealand               7.294600
# North America                           7.174700
# Western Europe                          6.789330
# Latin America and Caribbean             6.062650
# Eastern Asia                            5.651567
# Central and Eastern Europe              5.427807
# Southeastern Asia                       5.323172
# Middle East and Northern Africa         5.321253
# Southern Asia                           4.580657
# Sub-Saharan Africa                      4.211879

# %%
import matplotlib.pyplot as plt

xticklabels = list(media_por_regiao.index)
fig = plt.figure(1, figsize = (15, 7))
ax = fig.add_subplot(111)
plt.bar(x = media_por_regiao.index, height = media_por_regiao['Happiness Score'])
ax.set_xticklabels(xticklabels, fontsize = 13, rotation = 45, ha = 'right')
ax.set_yticklabels(np.arange(0, 9), fontsize = 15)
plt.xlabel('Regions', fontsize = 15)
plt.ylabel('Hapiness Score', fontsize = 15)
plt.show();
# Out:
# C:\Users\Daniel Garcia\AppData\Local\Temp\ipykernel_8112\1422782610.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels, fontsize = 13, rotation = 45, ha = 'right')
# C:\Users\Daniel Garcia\AppData\Local\Temp\ipykernel_8112\1422782610.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.arange(0, 9), fontsize = 15)
